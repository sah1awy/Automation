# %%
from pycaret.classification import *

# %%
from pycaret.datasets import get_data

# %%
data = get_data("credit")
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1      90000    2          2         2   34      0      0      0      0
# 2      50000    2          2         1   37      0      0      0      0
# 3      50000    1          2         1   57     -1      0     -1      0
# 4      50000    1          1         2   37      0      0      0      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 2      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 3      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
# 4      0  ...    19394.0    19619.0    20024.0    2500.0    1815.0     657.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
data.shape
# Out:
# (24000, 24)

# %%
data.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1      90000    2          2         2   34      0      0      0      0
# 2      50000    2          2         1   37      0      0      0      0
# 3      50000    1          2         1   57     -1      0     -1      0
# 4      50000    1          1         2   37      0      0      0      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 2      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 3      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
# 4      0  ...    19394.0    19619.0    20024.0    2500.0    1815.0     657.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
data.tail()
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 23995      80000    1          2         2   34      2      2      2      2
# 23996     150000    1          3         2   43     -1     -1     -1     -1
# 23997      30000    1          2         2   37      4      3      2     -1
# 23998      80000    1          3         1   41      1     -1      0      0
# 23999      50000    1          2         1   46      0      0      0      0
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 23995      2  ...    77519.0    82607.0    81158.0    7000.0    3500.0
# 23996      0  ...     8979.0     5190.0        0.0    1837.0    3526.0
# 23997      0  ...    20878.0    20582.0    19357.0       0.0       0.0
# 23998      0  ...    52774.0    11855.0    48944.0   85900.0    3409.0
# 23999      0  ...    36535.0    32428.0    15313.0    2078.0    1800.0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24000 entries, 0 to 23999
# Data columns (total 24 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LIMIT_BAL  24000 non-null  int64
#  1   SEX        24000 non-null  int64
#  2   EDUCATION  24000 non-null  int64
#  3   MARRIAGE   24000 non-null  int64
#  4   AGE        24000 non-null  int64
#  5   PAY_1      24000 non-null  int64
#  6   PAY_2      24000 non-null  int64
#  7   PAY_3      24000 non-null  int64
#  8   PAY_4      24000 non-null  int64
#  9   PAY_5      24000 non-null  int64
#  10  PAY_6      24000 non-null  int64
#  11  BILL_AMT1  24000 non-null  float64
#  12  BILL_AMT2  24000 non-null  float64
#  13  BILL_AMT3  24000 non-null  float64
#  14  BILL_AMT4  24000 non-null  float64
#  15  BILL_AMT5  24000 non-null  float64
#  16  BILL_AMT6  24000 non-null  float64
#  17  PAY_AMT1   24000 non-null  float64
#  18  PAY_AMT2   24000 non-null  float64
# ...

# %%
data.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=24000, step=1)

# %%
data.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    24000.000000  24000.000000  24000.000000  24000.000000  24000.000000
# mean    167876.403333      1.600917      1.850958      1.553000     35.446708
# std     129907.454723      0.489720      0.787361      0.521331      9.180845
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_1         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  24000.000000  24000.000000  24000.000000  24000.000000  24000.000000
# mean      -0.023875     -0.140500     -0.170000     -0.221500     -0.266833
# ...

# %%
training = data.sample(frac=0.9, random_state=42,replace=False)

# %%
testing = data.drop(training.index)

# %%
training.shape
# Out:
# (21600, 24)

# %%
testing.shape
# Out:
# (2400, 24)

# %%
clf = setup(data=training,target='default')
# Out:
# <style type="text/css">
# #T_fee68_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fee68">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fee68_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fee68_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fee68_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fee68_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fee68_row0_col1" class="data row0 col1" >946</td>
#     </tr>
#     <tr>
#       <th id="T_fee68_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fee68_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fee68_row1_col1" class="data row1 col1" >default</td>
#     </tr>
#     <tr>
#       <th id="T_fee68_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_a09a7 th {
#   text-align: left;
# }
# ...

# %%
print(best_model)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=946, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
rf = create_model("rf")
# Out:
# <style type="text/css">
# #T_6c494_row10_col0, #T_6c494_row10_col1, #T_6c494_row10_col2, #T_6c494_row10_col3, #T_6c494_row10_col4, #T_6c494_row10_col5, #T_6c494_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6c494">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c494_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6c494_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6c494_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6c494_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6c494_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6c494_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6c494_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
rf_tuned = tune_model(rf)
# Out:
# <style type="text/css">
# #T_ccbee_row10_col0, #T_ccbee_row10_col1, #T_ccbee_row10_col2, #T_ccbee_row10_col3, #T_ccbee_row10_col4, #T_ccbee_row10_col5, #T_ccbee_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ccbee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccbee_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ccbee_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ccbee_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ccbee_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ccbee_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ccbee_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ccbee_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
pred = predict_model(rf_tuned,data=testing)
# Out:
# <style type="text/css">
# </style>
# <table id="T_93563">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93563_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_93563_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_93563_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_93563_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_93563_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_93563_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_93563_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_93563_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93563_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_93563_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
# ...

# %%
pred
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 9         260000    2          1         2   51     -1     -1     -1     -1
# 11        250000    1          1         2   29      0      0      0      0
# 13         20000    1          1         2   24      0      0      2      2
# 55         80000    1          1         2   31     -1     -1     -1     -1
# 60        300000    2          1         1   45     -1     -1     -1     -1
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 23981     420000    1          1         2   34      0      0      0      0
# 23982     180000    1          1         1   32     -2     -2     -2     -2
# 23992     140000    1          2         1   41      0      0      0      0
# 23996     150000    1          3         2   43     -1     -1     -1     -1
# 23998      80000    1          3         1   41      1     -1      0      0
#
# ...

# %%
from pycaret.utils.generic import check_metric

# %%
check_metric(pred['default'],pred['prediction_label'],metric="Accuracy")
# Out:
# 0.8062
